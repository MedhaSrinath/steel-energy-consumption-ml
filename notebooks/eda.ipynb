# %% [markdown]
# # Exploratory Data Analysis
#
# Use this notebook to inspect the steel industry dataset, check data quality, and summarize key variables.

# %%
from pathlib import Path

import pandas as pd

DATA_PATH = Path('..') / 'data' / 'steel_industry_data.csv'
df = pd.read_csv(DATA_PATH)
df.head()
